# %%
from typing import List

from llms.agent.rag.ingestion import ingest_data

# %%
path_input_data: str = '../../data/tmp'
vector_store_url: str = 'http://localhost:6333'
collection_name: str = 'data'
document_id_key: str = 'file_name'
is_hybrid: bool = True
is_recreate_collection: bool = True
embeddings_model_name: str = 'BAAI/bge-small-en-v1.5'
chunk_size: int = 100
chunk_overlap: int = 0
text_template: str = "<metadata>\n{metadata_str}\n</metadata>\n\n<content>\n{content}\n</content>"
keys_to_exclude: List[str] = ["page_label", "file_path"]
keys_to_include: List[str] = []

ingest_data(
    path_input_data=path_input_data,
    vector_store_url=vector_store_url,
    collection_name=collection_name,
    is_hybrid=is_hybrid,
    is_recreate_collection=is_recreate_collection,
    document_id_key=document_id_key,
    embeddings_model_name=embeddings_model_name,
    chunk_size=chunk_size,
    chunk_overlap=chunk_overlap,
    text_template=text_template,
    keys_to_exclude=keys_to_exclude,
    keys_to_include=keys_to_include,
)
